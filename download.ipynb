# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6mWUqKj3IcGVfFNq8jMZ")
project = rf.workspace("mai-danh-hieu-laury").project("nine-dash-line-coco-2")
version = project.version(5)
dataset = version.download("coco")
# Out:
# ...
#   Using cached pillow-12.1.1-cp310-cp310-win_amd64.whl (7.0 MB)
# ...
#   Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# ...
#   Using cached requests-2.33.0-py3-none-any.whl (65 kB)
# ...
#   Using cached charset_normalizer-3.4.6-cp310-cp310-win_amd64.whl (154 kB)
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\Admin\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to nine-dash-line-coco-2-5 in coco:: 100%|██████████| 11634/11634 [00:04<00:00, 2602.57it/s]

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("hiumaidanh/nine-dash")

print("Path to dataset files:", path)
